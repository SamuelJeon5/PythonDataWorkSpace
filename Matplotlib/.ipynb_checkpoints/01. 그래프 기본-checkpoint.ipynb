# %% [markdown]
# # Matplotlib
# 다양한 형태의 그래프를 통해서 데이터 시각화를 할 수 있는 라이브러리

# %%
import matplotlib.pyplot as plt

# %% [markdown]
# ##  1. 그래프 기본

# %%
x = [1,2,3]
y = [2,4,8]

plt.plot(x, y)

# %%
print(plt.plot(x, y))
# Out:
# [<matplotlib.lines.Line2D object at 0x000002016AFD8C40>]

# %%
plt.plot(x,y)
plt.show()

# %% [markdown]
# ## Title 설정

# %%
plt.plot(x,y)
plt.title('Line Graph')
# Out:
# Text(0.5, 1.0, 'Line Graph')

# %%
plt.plot(x,y)
plt.title('꺾은 선 그래프')
# Out:
# Text(0.5, 1.0, '꺾은 선 그래프')
# C:\Users\souls\anaconda3\envs\practice\lib\site-packages\IPython\core\events.py:89: UserWarning: Glyph 44734 (\N{HANGUL SYLLABLE GGEOGG}) missing from current font.
#   func(*args, **kwargs)
# C:\Users\souls\anaconda3\envs\practice\lib\site-packages\IPython\core\events.py:89: UserWarning: Glyph 51008 (\N{HANGUL SYLLABLE EUN}) missing from current font.
#   func(*args, **kwargs)
# C:\Users\souls\anaconda3\envs\practice\lib\site-packages\IPython\core\events.py:89: UserWarning: Glyph 49440 (\N{HANGUL SYLLABLE SEON}) missing from current font.
#   func(*args, **kwargs)
# C:\Users\souls\anaconda3\envs\practice\lib\site-packages\IPython\core\events.py:89: UserWarning: Glyph 44536 (\N{HANGUL SYLLABLE GEU}) missing from current font.
#   func(*args, **kwargs)
# C:\Users\souls\anaconda3\envs\practice\lib\site-packages\IPython\core\events.py:89: UserWarning: Glyph 47000 (\N{HANGUL SYLLABLE RAE}) missing from current font.
#   func(*args, **kwargs)
# C:\Users\souls\anaconda3\envs\practice\lib\site-packages\IPython\core\events.py:89: UserWarning: Glyph 54532 (\N{HANGUL SYLLABLE PEU}) missing from current font.
#   func(*args, **kwargs)
# C:\Users\souls\anaconda3\envs\practice\lib\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 44734 (\N{HANGUL SYLLABLE GGEOGG}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\souls\anaconda3\envs\practice\lib\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 51008 (\N{HANGUL SYLLABLE EUN}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\souls\anaconda3\envs\practice\lib\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 49440 (\N{HANGUL SYLLABLE SEON}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\souls\anaconda3\envs\practice\lib\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 44536 (\N{HANGUL SYLLABLE GEU}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\souls\anaconda3\envs\practice\lib\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 47000 (\N{HANGUL SYLLABLE RAE}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\souls\anaconda3\envs\practice\lib\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 54532 (\N{HANGUL SYLLABLE PEU}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)

# %% [markdown]
# ## 한글 폰트 설정

# %%
import matplotlib
matplotlib.rcParams['font.family'] = 'Malgun Gothic' # Windows
# matplotlib.rcParams['font.family'] = 'AppleGothic' # Mac
matplotlib.rcParams['font.size'] = 15 # 글자 크기
matplotlib.rcParams['axes.unicode_minus'] = False # 한글 폰트 사용 시, 마이너스 글자가 깨지는 현상을 해결

# %%
import matplotlib.font_manager as fm
fm.fontManager.ttflist # 사용 가능한 폰트 확인
[f.name for f in fm.fontManager.ttflist]
# Out:
# ['DejaVu Sans',
#  'cmmi10',
#  'DejaVu Serif',
#  'STIXNonUnicode',
#  'cmtt10',
#  'STIXGeneral',
#  'cmr10',
#  'STIXSizeOneSym',
#  'STIXSizeThreeSym',
#  'STIXSizeTwoSym',
#  'cmss10',
#  'STIXSizeFourSym',
#  'cmex10',
#  'DejaVu Serif',
#  'DejaVu Serif',
#  'STIXNonUnicode',
#  'DejaVu Sans Mono',
#  'STIXNonUnicode',
#  'DejaVu Serif Display',
#  'DejaVu Sans',
#  'STIXGeneral',
#  'DejaVu Sans Mono',
#  'STIXSizeThreeSym',
#  'DejaVu Sans',
#  'STIXGeneral',
#  'STIXSizeOneSym',
#  'STIXSizeTwoSym',
#  'DejaVu Sans Mono',
#  'STIXNonUnicode',
#  'DejaVu Sans Mono',
#  'STIXGeneral',
#  'cmsy10',
#  'STIXSizeFourSym',
#  'DejaVu Serif',
#  'DejaVu Sans Display',
#  'STIXSizeFiveSym',
#  'cmb10',
#  'DejaVu Sans',
#  'HYporM',
#  'Script MT Bold',
#  'Tempus Sans ITC',
#  'Verdana',
#  'Mongolian Baiti',
#  'Segoe UI',
#  'Palatino Linotype',
#  '??????',
#  'Gill Sans MT',
#  'High Tower Text',
#  'Segoe UI',
#  'Courier New',
#  'Lucida Bright',
#  'Sitka',
#  'Lucida Bright',
#  'GoudyOlSt BT',
#  'Segoe UI Variable',
#  'Arial',
#  'DomCasual BT',
#  'Franklin Gothic Medium Cond',
#  'Newtext Bk BT',
#  'CentSchbook BT',
#  'Lucida Sans Typewriter',
#  'Haan Somang B',
#  'Viner Hand ITC',
#  'MSugiHeulim',
#  'Microsoft New Tai Lue',
#  'Yj DWMMOOGJO',
#  'Baskerville Old Face',
#  'Arial',
#  'Kunstler Script',
#  'Franklin Gothic Demi Cond',
#  'Bodoni MT',
#  'Goudy Stout',
#  'Segoe Fluent Icons',
#  'Goudy Old Style',
#  'Calibri',
#  'Rockwell Condensed',
#  'Corbel',
#  'Rockwell',
#  'Swis721 BT',
#  'Cambria',
#  'Ink Free',
#  'Microsoft New Tai Lue',
#  'Harrington',
#  'Yj BONMOKGAK Medium ',
#  'Gill Sans MT Ext Condensed Bold',
#  'Arial',
#  'AmeriGarmnd BT',
#  'Verdana',
#  'Haan YGodic 230',
#  '??????',
#  'Colonna MT',
#  'Myanmar Text',
#  'Perpetua Titling MT',
#  'Tw Cen MT Condensed',
#  'Baskerville BT',
#  'Courier New',
#  'Arial Rounded MT Bold',
#  'Symbol',
#  'Gloucester MT Extra Condensed',
#  'Century',
#  'MurrayHill Bd BT',
#  'Lucida Handwriting',
#  'Lucida Bright',
#  'Gill Sans Ultra Bold',
#  'Bahnschrift',
#  'BroadwayEngraved BT',
#  'Calisto MT',
#  'Candara',
#  'HYhaeseo',
#  'Agency FB',
#  'Segoe Script',
#  'Dubai',
#  'Times New Roman',
#  'Gulim',
#  'Copperplate Gothic Light',
#  'Gill Sans Ultra Bold Condensed',
#  'French Script MT',
#  'OCR-A BT',
#  'Yj DOOLGI Medium',
#  'Ebrima',
#  'Lucida Fax',
#  '??????',
#  'HYnamM',
#  'Microsoft Tai Le',
#  'Yj BLOCK Medium',
#  'Haan Somang M',
#  'Bell MT',
#  'ahn2006-L',
#  'Segoe UI',
#  'CentSchbook BT',
#  'Microsoft YaHei',
#  'HYcysM',
#  'Microsoft JhengHei',
#  'Yj SHANALL Medium ',
#  'Perpetua Titling MT',
#  'Georgia',
#  'Rockwell',
#  'Microsoft YaHei',
#  'Haan YGodic 240',
#  'Kristen ITC',
#  'HYbdaM',
#  'Bodoni Bk BT',
#  'Georgia',
#  'Bell MT',
#  'Jokerman',
#  'Snap ITC',
#  'Nirmala UI',
#  'YJ INJANG Medium',
#  'Bookshelf Symbol 7',
#  'Yu Gothic',
#  'Comic Sans MS',
#  'Engravers MT',
#  'HCR Dotum',
#  'Yj WADAG Medium',
#  'Trebuchet MS',
#  'HYnamL',
#  'Book Antiqua',
#  'SimSun-ExtB',
#  'Book Antiqua',
#  'Century Gothic',
#  'Courier New',
#  'HYsupM',
#  'Lucida Sans Typewriter',
#  'AmeriGarmnd BT',
#  'Yj SOSEL SemiBold',
#  'HCR Batang',
#  'Eras Bold ITC',
#  'Verdana',
#  'HCR Dotum',
#  'ahn2006-B',
#  'Palace Script MT',
#  'Leelawadee UI',
#  'Calisto MT',
#  'Franklin Gothic Heavy',
#  'Niagara Engraved',
#  'Book Antiqua',
#  'Microsoft PhagsPa',
#  'Segoe UI Symbol',
#  'Bookman Old Style',
#  'HYmjrE',
#  'Haan Baekje B',
#  'Times New Roman',
#  'Microsoft Tai Le',
#  'Berlin Sans FB',
#  'Lucida Sans',
#  'YJ BELLA Medium',
#  'Cascadia Mono',
#  'Haan YHead L',
#  'Bell MT',
#  'Poor Richard',
#  'Stencil',
#  'Lucida Fax',
#  'HYkanB',
#  'MDotum',
#  'Haan YGodic 250',
#  'Century Schoolbook',
#  '????',
#  'Calisto MT',
#  'Playbill',
#  'Rage Italic',
#  'HYdnkB',
#  'Chiller',
#  'MBatang',
#  'Goudy Old Style',
#  'AmeriGarmnd BT',
#  'Ravie',
#  'HYgsrB',
#  'GoudyOlSt BT',
#  'Century Gothic',
#  'Consolas',
#  'Courier10 BT',
#  '? ??',
#  'Candara',
#  'Candara',
#  'MS Reference Sans Serif',
#  'OCR A Extended',
#  'Yu Gothic',
#  'Bookman Old Style',
#  'Haan Cooljazz B',
#  'HYtbrB',
#  'Calisto MT',
#  'Bookman Old Style',
#  'Cooper Blk BT',
#  'HYwulM',
#  'Corbel',
#  'Impact',
#  'Candara',
#  'HYsupB',
#  '????',
#  'Bauhaus 93',
#  'Copperplate Gothic Bold',
#  'Constantia',
#  'Wingdings',
#  'Century Schoolbook',
#  'Bodoni MT',
#  'Dubai',
#  'Times New Roman',
#  'Franklin Gothic Medium',
#  'Wingdings 2',
#  'FuturaBlack BT',
#  'Rockwell',
#  'HYwulB',
#  'Consolas',
#  'Tw Cen MT Condensed Extra Bold',
#  'Palatino Linotype',
#  'Rockwell',
#  'Franklin Gothic Demi',
#  'Arial',
#  'Book Antiqua',
#  'Berlin Sans FB',
#  'Segoe UI',
#  '??????',
#  'Eras Light ITC',
#  'Constantia',
#  'Trebuchet MS',
#  'Palatino Linotype',
#  'Gabriola',
#  '???',
#  'MS Outlook',
#  'Corbel',
#  'Perpetua',
#  'Lucida Calligraphy',
#  'Perpetua',
#  'CommercialScript BT',
#  'Webdings',
#  'Roboto',
#  'Edwardian Script ITC',
#  'Segoe UI',
#  'GoudyOlSt BT',
#  'Garamond',
#  'Gadugi',
#  'Monotype Corsiva',
#  'MHunmin',
#  'Constantia',
#  'Berlin Sans FB Demi',
#  'Malgun Gothic',
#  'Arial',
#  'Haansoft Batang',
#  'Candara',
#  'Haan Cooljazz L',
#  'Sylfaen',
#  'HYkanM',
#  'Onyx',
#  'Century Gothic',
#  'HYgtrE',
#  'Bodoni MT',
#  'Franklin Gothic Book',
#  'MDArt',
#  'Sitka',
#  'Orbit-B BT',
#  'Bodoni Bd BT',
#  'Bodoni MT',
#  'Corbel',
#  'Goudy Old Style',
#  'Lucida Sans Unicode',
#  'Yj BUTGOT Light ',
#  'Corbel',
#  'Bodoni MT',
#  'Bernard MT Condensed',
#  'ahn2006-M',
#  'MSugiJeong',
#  'Haan Sollip M',
#  'Segoe UI',
#  'Segoe Script',
#  'Calibri',
#  'Matura MT Script Capitals',
#  'Lucida Sans',
#  'HCR Batang Ext',
#  'Yj NANCHO Medium',
#  'Bodoni Bd BT',
#  'Curlz MT',
#  'Comic Sans MS',
#  'Footlight MT Light',
#  'Constantia',
#  'HYbsrB',
#  'Elephant',
#  'Calibri',
#  'BrushScript BT',
#  'Tahoma',
#  'Franklin Gothic Medium',
#  'Lucida Sans Typewriter',
#  'LG PC',
#  'Segoe UI Emoji',
#  'HYsnrL',
#  'Arial',
#  'Swis721 BT',
#  'Segoe UI Historic',
#  'MDSol',
#  'Bodoni MT',
#  'AmeriGarmnd BT',
#  'Microsoft Himalaya',
#  'Franklin Gothic Demi',
#  'Yu Gothic',
#  'Microsoft YaHei',
#  'Nirmala UI',
#  'Georgia',
#  'Cambria',
#  'Courier10 BT',
#  'Georgia',
#  'MDGaesung',
#  'Comic Sans MS',
#  'Stencil BT',
#  'Haan YHead B',
#  'Nirmala UI',
#  'Elephant',
#  'Vivaldi',
#  'MJemokBatang',
#  'Harlow Solid Italic',
#  'Yj BACDOO Bold ',
#  'Tw Cen MT',
#  'Freestyle Script',
#  'Lucida Sans Typewriter',
#  'Centaur',
#  'Malgun Gothic',
#  'Lucida Sans',
#  'Californian FB',
#  'Malgun Gothic',
#  'Arial',
#  'HCR Dotum Ext',
#  'Niagara Solid',
#  'Pristina',
#  'Comic Sans MS',
#  'Trebuchet MS',
#  'Segoe Print',
#  'Verdana',
#  'Californian FB',
#  'Gill Sans MT',
#  'Cambria',
#  'Algerian',
#  'Orator10 BT',
#  'MingLiU-ExtB',
#  'Garamond',
#  'Haan Sollip B',
#  'Segoe UI',
#  'Cooper Blk BT',
#  'Bodoni MT',
#  'Garamond',
#  'Batang',
#  'Cooper Black',
#  '????',
#  'Bookman Old Style',
#  'Hobo BT',
#  'Tw Cen MT',
#  'Agency FB',
#  'Arial',
#  'Rockwell Extra Bold',
#  'Segoe UI',
#  'Magneto',
#  'Haan YHead M',
#  'Microsoft JhengHei',
#  'Rockwell Condensed',
#  'Tw Cen MT Condensed',
#  '??????',
#  'Consolas',
#  'SimSun',
#  '??????',
#  'BernhardFashion BT',
#  '??????',
#  'Perpetua',
#  'HYgprM',
#  'Leelawadee UI',
#  'Eras Medium ITC',
#  'Perpetua',
#  'Brush Script MT',
#  'Segoe Print',
#  'Haettenschweiler',
#  'Javanese Text',
#  'Haan Sale M',
#  'Lucida Fax',
#  'Gill Sans MT',
#  'Microsoft Yi Baiti',
#  'High Tower Text',
#  'Juice ITC',
#  'CentSchbook BT',
#  'Tw Cen MT',
#  'Mistral',
#  'Felix Titling',
#  'Segoe UI',
#  'Sans Serif Collection',
#  'Vladimir Script',
#  'Californian FB',
#  'Blackadder ITC',
#  'Cambria',
#  'Yj INITIALPOSITIVE Medium',
#  'Lucida Sans',
#  'Calibri',
#  'HYsanB',
#  'Gill Sans MT Condensed',
#  'Showcard Gothic',
#  'Haan Sale B',
#  'Courier New',
#  'Franklin Gothic Book',
#  'Maiandra GD',
#  'Arial',
#  'Eras Demi ITC',
#  'Britannic Bold',
#  'Bodoni MT',
#  'Bodoni Bk BT',
#  'Wide Latin',
#  'Bradley Hand ITC',
#  'Liberty BT',
#  'Segoe UI',
#  'Yj GABI',
#  'MS Gothic',
#  'Dubai',
#  'Tw Cen MT',
#  'Modern No. 20',
#  'Broadway',
#  'Haan Cooljazz M',
#  'Freehand591 BT',
#  '??????',
#  'Yj CHMSOOT Bold',
#  'MJemokGothic',
#  'Century Gothic',
#  'Lucida Fax',
#  'Cascadia Code',
#  'Franklin Gothic Heavy',
#  'GoudyOlSt BT',
#  'Papyrus',
#  'HYmprL',
#  'Corbel',
#  'Calibri',
#  'NewJumja',
#  'Yu Gothic',
#  'Dubai',
#  'MDEasop',
#  'HoloLens MDL2 Assets',
#  'Yj TEUNTEUN Bold',
#  'Palatino Linotype',
#  'Forte',
#  'Segoe MDL2 Assets',
#  'Ebrima',
#  'OCR-B-10 BT',
#  'Parchment',
#  'Haan Baekje M',
#  'Times New Roman',
#  'Informal Roman',
#  'Century Schoolbook',
#  'HCR Batang',
#  'Segoe UI',
#  'HYnamB',
#  'Gill Sans MT',
#  'MDAlong',
#  'MGungJeong',
#  'Lucida Bright',
#  'Microsoft JhengHei',
#  'Candara',
#  'Century Schoolbook',
#  'Gigi',
#  'Blippo Blk BT',
#  'Microsoft PhagsPa',
#  'Trebuchet MS',
#  'Tahoma',
#  'Yj GOTGAE Medium',
#  'HYbdaL',
#  'HYdnkM',
#  'Calibri',
#  'MS Reference Specialty',
#  'Segoe UI',
#  'Gadugi',
#  'Yj MAEHWA  SemiBold',
#  'Consolas',
#  'Bodoni MT',
#  'MGungHeulim',
#  'Bodoni MT',
#  '??????',
#  'MT Extra',
#  'ParkAvenue BT',
#  'Bodoni MT',
#  'Castellar',
#  'Myanmar Text',
#  'Wingdings 3',
#  'FZSong_Superfont',
#  'CentSchbook BT',
#  'HyhwpEQ',
#  'Haansoft Dotum',
#  'Imprint MT Shadow',
#  'Microsoft Sans Serif',
#  'Leelawadee UI',
#  'MV Boli',
#  'Lucida Console',
#  'Old English Text MT']

# %%
plt.plot(x,y)
plt.title('꺾은 선 그래프')
# Out:
# Text(0.5, 1.0, '꺾은 선 그래프')

# %%
plt.plot([-1, 0, 1], [-5,-1,2])
